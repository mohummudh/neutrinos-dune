# %%
from uproot_io import Events, View
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

# %%
TCLx = np.load("Trk_x_like.npy")
TCLeff = np.load("Trk_eff_like.npy")
TCLerr = np.load("Trk_err_like.npy")

SCLx = np.load("Shw_x_like.npy")
SCLeff = np.load("Shw_eff_like.npy")
SCLerr = np.load("Shw_err_like.npy")

TPLx = np.load("Trk_pan_x_like.npy")
TPLeff = np.load("Trk_pan_eff_like.npy")
TPLerr = np.load("Trk_pan_err_like.npy")

SPLx = np.load("Shw_pan_x_like.npy")
SPLeff = np.load("Shw_pan_eff_like.npy")
SPLerr = np.load("Shw_pan_err_like.npy")

TCBx = np.load("Trk_x_BDT.npy")
TCBeff = np.load("Trk_eff_BDT.npy")
TCBerr = np.load("Trk_err_BDT.npy")

SCBx = np.load("Shw_x_BDT.npy")
SCBeff = np.load("Shw_eff_BDT.npy")
SCBerr = np.load("Shw_err_BDT.npy")

TPBx = np.load("Trk_pan_x_BDT.npy")
TPBeff = np.load("Trk_pan_eff_BDT.npy")
TPBerr = np.load("Trk_pan_err_BDT.npy")

SPBx = np.load("Shw_pan_x_BDT.npy")
SPBeff = np.load("Shw_pan_eff_BDT.npy")
SPBerr = np.load("Shw_pan_err_BDT.npy")

# %%
plt.errorbar(TCLx, TCLeff, yerr=TCLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7, label='Likelihood')
plt.errorbar(TCBx, TCBeff, yerr=TCBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7, label='BDT')
plt.xlabel('n Hits in Particle')
plt.ylabel('Efficiency')
#plt.xticks(fontsize = 21)
#plt.yticks(fontsize = 21)
plt.ylim(0.5,1.02)
plt.legend()
plt.show()

plt.errorbar(SCLx, SCLeff, yerr=SCLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7)
plt.errorbar(SCBx, SCBeff, yerr=SCBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7)
plt.xlabel('n Hits in Particle')
plt.ylabel('Efficiency')
#plt.xticks(fontsize = 21)
#plt.yticks(fontsize = 21)
plt.ylim(0.5,1.02)
plt.show()

plt.errorbar(TPLx, TPLeff, yerr=TPLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7)
plt.errorbar(TPBx, TPBeff, yerr=TPBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7)
plt.xlabel('n Hits in Particle')
plt.ylabel('Efficiency')
#plt.xticks(fontsize = 21)
#plt.yticks(fontsize = 21)
plt.ylim(0.0,1.02)
plt.show()

plt.errorbar(SPLx, SPLeff, yerr=SPLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7)
plt.errorbar(SPBx, SPBeff, yerr=SPBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=7)
plt.xlabel('n Hits in Particle')
plt.ylabel('Efficiency')
#plt.xticks(fontsize = 21)
#plt.yticks(fontsize = 21)
plt.ylim(0.0,1.02)
plt.show()

# %%
#fig = plt.figure()
#gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
#(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
#fig.suptitle('Sharing x per column, y per row')


fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True)
ax1.errorbar(TCLx, TCLeff, yerr=TCLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4, label='Likelihood')
ax1.errorbar(TCBx, TCBeff, yerr=TCBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4, label='BDT')
ax2.errorbar(SCLx, SCLeff, yerr=SCLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4)
ax2.errorbar(SCBx, SCBeff, yerr=SCBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4)
ax3.errorbar(TPLx, TPLeff, yerr=TPLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4)
ax3.errorbar(TPBx, TPBeff, yerr=TPBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4)
ax4.errorbar(SPLx, SPLeff, yerr=SPLerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4)
ax4.errorbar(SPBx, SPBeff, yerr=SPBerr, fmt='o', elinewidth=1, ecolor='grey', capsize=2, ms=4)

for ax in fig.get_axes():
    ax.label_outer()
