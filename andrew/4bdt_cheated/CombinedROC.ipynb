# %%
from uproot_io import Events, View
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

# %%
PPlike = np.load("PP_Likelihood.npy")
PElike = np.load("PE_Likelihood.npy")
CPlike = np.load("CP_Likelihood.npy")
CElike = np.load("CE_Likelihood.npy")
PPBDT = np.load("PP_BDT.npy")
PEBDT = np.load("PE_BDT.npy")
CPBDT = np.load("CP_BDT.npy")
CEBDT = np.load("CE_BDT.npy")

# %%
plt.plot(CPlike, CElike, label='Likelihood')
plt.plot(CPBDT, CEBDT, label='BDT')
#plt.scatter(CPlike, CElike)
#plt.scatter(CPBDT, CEBDT)
plt.scatter(1, 1, s=75, c='r')
plt.xlabel('Purity', fontsize=25)
plt.ylabel('Efficiency', fontsize=25)
#plt.title('ROC Curve for Track Likelihood')
plt.xticks(np.arange(0.6, 1.1, step=0.1), fontsize = 21)
plt.yticks(np.arange(0.6, 1.1, step=0.1), fontsize = 21)
plt.xlim(0.575,1.025)
plt.ylim(0.575,1.025)
plt.legend(fontsize=14)
plt.show()

plt.plot(PPlike, PElike, label='Likelihood')
plt.plot(PPBDT, PEBDT, label='BDT')
#plt.scatter(PPlike, PElike)
#plt.scatter(PPBDT, PEBDT)
plt.scatter(1, 1, s=75, c='r')
plt.xlabel('Purity', fontsize=25)
plt.ylabel('Efficiency', fontsize=25)
#plt.title('ROC Curve for Track Likelihood')
plt.xticks(np.arange(0.6, 1.1, step=0.1), fontsize = 21)
plt.yticks(np.arange(0.6, 1.1, step=0.1), fontsize = 21)
plt.xlim(0.575,1.025)
plt.ylim(0.575,1.025)
plt.show()
