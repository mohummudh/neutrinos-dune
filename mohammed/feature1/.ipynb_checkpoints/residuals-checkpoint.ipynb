# %%
import numpy as np
import matplotlib.pyplot as plt

from uproot_io import Events, View

# %%
# Interaction type lookup
import csv
interaction_dictionary = {}
with open('interactions.csv') as f:
    reader = csv.DictReader(f)
    for row in reader:
        key = int(row.pop('Idx'))
        interaction = row.pop('Interaction')
        interaction_dictionary[key] = interaction
# print(interaction_dictionary)

# %%
events = Events("PandoraRecoFile_1.root")

# %%
events.event_number
# Out:
# array([   0,    0,    0, ..., 9208, 9208, 9208], dtype=int32)

# %%
events.mc_pdg
# Out:
# array([  22,   22, 2212, ...,   22,   22,   22], dtype=int32)

# %%
def plotparticles(event_number):
    idx = np.where(events.event_number == event_number)[0]
    
    residuals = np.array([])
    
    for i in idx:
        x = events.reco_hits_x_w[i]
        z = events.reco_hits_w[i]
        pdg = events.mc_pdg[i]
        
        if x.size == 0:
            continue
            
        else:
            m, c = np.polyfit(x, z, 1)
        
        pred = m * x + c
        resd = np.mean(np.abs(z - pred))
        residuals = np.append(residuals, resd)

        
#         plt.scatter(x, z, s=10)
#         plt.plot(x, pred)
        print(f"Particle {i} and Particle type {pdg}: {resd}")
    
    vx = events.true_neutrino_vtx_x[idx[0]]
    vz = events.true_neutrino_vtx_w[idx[0]]
#     plt.scatter(vx, vz, c='red', s=50)
    
    typ = events.interaction_type[idx[0]]
    name = interaction_dictionary[typ]
    
#     plt.title(f'Interaction Type: {name}')
#     plt.xlabel('Time')
#     plt.ylabel('W Wire')
    
    return residuals

# %%
eventNumbers = list(set(events.event_number))
# print(eventNumbers)

# %%
for i in eventNumbers:
    r = plotparticles(i)§
    plt.hist(r, 21)
# Out:
# Particle 0 and Particle type 22: 0.7124808430671692
# Particle 1 and Particle type 22: 0.2994854152202606
# Particle 2 and Particle type 2212: 0.7960902452468872
# Particle 3 and Particle type 13: 1.1201071739196777
# Particle 4 and Particle type 0: 0.8018354773521423
# Particle 5 and Particle type 2212: 0.0440266914665699
# Particle 6 and Particle type 2212: 0.05460204929113388
# Particle 7 and Particle type 2212: 0.08327636867761612
# Particle 8 and Particle type 22: 39.54526138305664
# Particle 10 and Particle type 0: 0.2931315004825592
# Particle 11 and Particle type 211: 0.5001527667045593
# Particle 12 and Particle type 2212: 0.6953619718551636
# Particle 13 and Particle type 13: 4.39374303817749
# Particle 14 and Particle type 0: 0.1831156462430954
# Particle 15 and Particle type 0: 8.129679679870605
# Particle 17 and Particle type 13: 3.8653552532196045
# Particle 18 and Particle type 2212: 0.07099796831607819
# Particle 19 and Particle type 2212: 0.20164871215820312
# Particle 20 and Particle type 0: 2.0159640312194824
# Particle 21 and Particle type 2212: 0.0019938151817768812
# Particle 22 and Particle type 2212: 0.17008666694164276
# Particle 23 and Particle type -211: 2.0474741458892822
# Particle 24 and Particle type 2212: 0.15437668561935425
# Particle 25 and Particle type 13: 23.69831657409668
# Particle 26 and Particle type 2212: 0.0428466796875
# Particle 27 and Particle type 211: 0.8795267939567566
# Particle 28 and Particle type -211: 37.299041748046875
# Particle 29 and Particle type 22: 0.7773491144180298
# Particle 30 and Particle type 22: 0.31793212890625
# Particle 31 and Particle type 0: 0.15995456278324127
# Particle 32 and Particle type -211: 0.27420562505722046
# Particle 33 and Particle type 2212: 0.2828114926815033
# Particle 34 and Particle type 2212: 0.12370820343494415
# Particle 35 and Particle type 211: 0.22510863840579987
# Particle 36 and Particle type -11: 0.4810829162597656
# Particle 37 and Particle type -211: 0.0935341939330101
# Particle 38 and Particle type 2212: 0.164947509765625
# Particle 39 and Particle type 22: 0.5305032134056091
# Particle 40 and Particle type 13: 1.3507938385009766
# Particle 41 and Particle type 0: 0.1605089008808136
# Particle 43 and Particle type -11: 0.2401820570230484
# Particle 44 and Particle type 211: 0.49274682998657227
# Particle 45 and Particle type 13: 0.4549151360988617
# Particle 46 and Particle type 2212: 2.7920706272125244
# Particle 47 and Particle type -211: 0.2374698370695114
# Particle 48 and Particle type 2212: 2.4341046810150146
# Particle 49 and Particle type 2212: 0.3023321330547333
# Particle 50 and Particle type 2212: 7.563106536865234
# Particle 51 and Particle type 2212: 1.7816822528839111
# Particle 52 and Particle type 2212: 0.6753028631210327
# Particle 53 and Particle type 211: 5.7981157302856445
# Particle 54 and Particle type -211: 43.63508605957031
# Particle 55 and Particle type -211: 0.4687282145023346
# Particle 56 and Particle type 2212: 0.0374232716858387
# Particle 57 and Particle type 0: 0.0831298828125
# Particle 58 and Particle type 2212: 0.0771687850356102
# Particle 59 and Particle type 211: 14.321131706237793
# Particle 60 and Particle type 22: 44.166587829589844
# Particle 61 and Particle type 22: 3.72035813331604
# Particle 62 and Particle type 0: 2.6789603233337402
# Particle 63 and Particle type 0: 0.22709517180919647
# Particle 64 and Particle type 0: 1.458969235420227
# Particle 65 and Particle type 22: 1.7353938817977905
# Particle 66 and Particle type 0: 0.2430012971162796
# Particle 67 and Particle type 0: 0.04229736328125
# Particle 68 and Particle type 13: 19.18923568725586
# Particle 69 and Particle type 13: 2.601985216140747
# Particle 70 and Particle type 2212: 1.2252088785171509
# Particle 71 and Particle type 22: 3.914996385574341
# Particle 72 and Particle type 22: 0.5898545384407043
# Particle 73 and Particle type 13: 11.133161544799805
# Particle 74 and Particle type 2212: 0.6147022843360901
# Particle 75 and Particle type 22: 11.614067077636719
# Particle 76 and Particle type 2212: 0.029552113264799118
# Particle 77 and Particle type 22: 3.1255369186401367
# Particle 78 and Particle type -11: 1.8995065689086914
# Particle 79 and Particle type 0: 0.4217036962509155
# Particle 80 and Particle type 22: 1.6893082857131958
# Particle 81 and Particle type -11: 0.16472278535366058
# Particle 82 and Particle type 13: 0.4040374755859375
# Particle 83 and Particle type 211: 0.01239013671875
# Particle 84 and Particle type 211: 0.0600382499396801
# Particle 85 and Particle type 22: 0.3034361004829407
# Particle 86 and Particle type 211: 1.3084778785705566
# Particle 87 and Particle type -211: 2.008065700531006
# Particle 88 and Particle type 211: 0.0380723737180233
# Particle 89 and Particle type 13: 11.555865287780762
# Particle 90 and Particle type 13: 7.160167217254639
# Particle 91 and Particle type 13: 1.1495441198349
# Particle 92 and Particle type 13: 0.5522132515907288
# Particle 93 and Particle type 0: 0.0768839493393898
# Particle 94 and Particle type 22: 0.1170298233628273
# Particle 96 and Particle type 0: 0.8306504487991333
# Particle 97 and Particle type 0: 1.0321913957595825
# Particle 98 and Particle type -211: 1.4815917015075684
# Particle 99 and Particle type 13: 11.379049301147461
# Particle 100 and Particle type 22: 45.67399978637695
# Particle 102 and Particle type 0: 0.2549917995929718
# Particle 103 and Particle type 13: 6.550034046173096
# Particle 104 and Particle type 0: 0.2090996652841568
# Particle 105 and Particle type 13: 0.2659465968608856
# Particle 106 and Particle type 211: 0.02260843850672245
# Particle 107 and Particle type 211: 0.18095970153808594
# Particle 108 and Particle type 211: 0.1581638902425766
# Particle 109 and Particle type -11: 0.1154378280043602
# Particle 110 and Particle type 2212: 0.4439782202243805
# Particle 111 and Particle type 2212: 0.0919036865234375
# Particle 112 and Particle type 13: 5.474192142486572
# Particle 113 and Particle type 13: 1.0700228214263916
# Particle 114 and Particle type 211: 1.6167610883712769
# Particle 115 and Particle type 2212: 0.8334538340568542
# Particle 116 and Particle type 2212: 3.764248847961426
# Particle 117 and Particle type 22: 0.4609375
# Particle 118 and Particle type 13: 0.6155571937561035
# Particle 119 and Particle type 2212: 0.31685569882392883
# Particle 120 and Particle type 2212: 0.0940755233168602
# Particle 121 and Particle type 2212: 0.1698455810546875
# Particle 122 and Particle type 13: 2.6862308979034424
# Particle 123 and Particle type 13: 0.36093971133232117
# Particle 124 and Particle type 13: 0.6884358525276184
# Particle 125 and Particle type 13: 0.3710065484046936
# Particle 126 and Particle type 2212: 0.1813134104013443
# Particle 127 and Particle type 2212: 0.856212854385376
# Particle 128 and Particle type 211: 1.0316509008407593
# Particle 129 and Particle type 13: 0.8477070927619934
# Particle 130 and Particle type 13: 2.657304048538208
# Particle 131 and Particle type 2212: 2.6364803314208984
# Particle 132 and Particle type 211: 0.7387242913246155
# Particle 133 and Particle type 211: 3.471614122390747
# Particle 134 and Particle type 22: 3.1223983764648438
# Particle 135 and Particle type 22: 0.8035675883293152
# Particle 136 and Particle type 211: 0.2516988217830658
# Particle 137 and Particle type -211: 0.6069555878639221
# Particle 138 and Particle type 13: 2.615107297897339
# Particle 139 and Particle type 2212: 2.1617703437805176
# Particle 140 and Particle type 2212: 0.0564400814473629
# Particle 141 and Particle type 13: 0.0872366800904274
# Particle 142 and Particle type 13: 1.5423778295516968
# Particle 143 and Particle type 211: 19.43257713317871
# Particle 144 and Particle type 1000010020: 0.5119900107383728
# Particle 145 and Particle type 211: 10.70959758758545
# Particle 146 and Particle type 2212: 0.04997190833091736
# Particle 147 and Particle type 0: 0.30181884765625
# Particle 148 and Particle type 2212: 0.3856388330459595
# Particle 149 and Particle type 2212: 0.0314737968146801
# Particle 151 and Particle type 211: 56.31608581542969
# Particle 152 and Particle type 0: 0.36137479543685913
# Particle 153 and Particle type 0: 0.2766045331954956
# Particle 154 and Particle type 211: 0.7796096801757812
# Particle 155 and Particle type 22: 12.588546752929688
# Particle 156 and Particle type 22: 0.2802560031414032
# Particle 157 and Particle type 2212: 0.07721306383609772
# Particle 158 and Particle type 2212: 0.0716203972697258
# Particle 159 and Particle type 13: 0.11165474355220795
# Particle 160 and Particle type 2212: 0.2726004421710968
# Particle 162 and Particle type 13: 19.590049743652344
# Particle 163 and Particle type 13: 0.5052136778831482
# Particle 164 and Particle type 0: 0.2082722932100296
# Particle 165 and Particle type 211: 1.874267578125
# Particle 166 and Particle type -211: 0.2420247346162796
# Particle 167 and Particle type 211: 1.1235002279281616
# Particle 168 and Particle type -211: 2.007331132888794
# Particle 169 and Particle type 2212: 1.4492753744125366
# Particle 170 and Particle type 211: 6.927761554718018
# Particle 171 and Particle type 211: 0.09046898782253265
# Particle 172 and Particle type 2212: 0.11176757514476776
# Particle 173 and Particle type 2212: 0.1064453125
# Particle 174 and Particle type 211: 4.564188480377197
# Particle 175 and Particle type 211: 1.226680040359497
# Particle 176 and Particle type 13: 0.5988492369651794
# Particle 177 and Particle type 13: 9.52738094329834
# Particle 178 and Particle type 0: 1.8237119913101196
# Particle 179 and Particle type 13: 0.14264094829559326
# Particle 180 and Particle type 0: 0.19600330293178558
# Particle 181 and Particle type 0: 0.1772104948759079
# Particle 182 and Particle type 2212: 0.0913001149892807
# Particle 183 and Particle type 22: 40.98672103881836
# Particle 184 and Particle type 22: 1.8667038679122925
# Particle 185 and Particle type 13: 0.3853759765625
# Particle 187 and Particle type 211: 0.922991931438446
# Particle 188 and Particle type 0: 0.09787790477275848
# Particle 189 and Particle type 2212: 0.09725248068571091
# Particle 190 and Particle type 2212: 1.0662057399749756
# Particle 191 and Particle type -211: 0.6362141966819763
# Particle 192 and Particle type -211: 1.240781545639038
# Particle 194 and Particle type 2212: 2.888958692550659
# Particle 195 and Particle type 2212: 0.0592549629509449
# Particle 196 and Particle type 0: 0.3239406943321228
# Particle 197 and Particle type 0: 0.2012677937746048
# Particle 198 and Particle type 2212: 0.1522623747587204
# Particle 199 and Particle type 13: 1.1656162738800049
# Particle 200 and Particle type 2212: 6.155124664306641
# Particle 201 and Particle type -211: 0.9882674217224121
# Particle 202 and Particle type 13: 16.922321319580078
# Particle 203 and Particle type 22: 10.95340347290039
# Particle 204 and Particle type 22: 9.393680572509766
# Particle 205 and Particle type 22: 0.1897146999835968
# Particle 206 and Particle type 2212: 0.01637776754796505
# Particle 207 and Particle type -211: 13.220392227172852
# Particle 208 and Particle type 2212: 5.8605241775512695
# Particle 209 and Particle type 2212: 0.12648148834705353
# Particle 210 and Particle type -211: 0.15981747210025787
# Particle 211 and Particle type 2212: 3.115605592727661
# Particle 212 and Particle type 2212: 0.11607666313648224
# Particle 213 and Particle type 2212: 0.08307494968175888
# Particle 214 and Particle type 2212: 1.7767713069915771
# Particle 215 and Particle type 2212: 0.0599517822265625
# Particle 216 and Particle type 211: 1.4411789178848267
# Particle 217 and Particle type 1000010020: 21.86326789855957
# Particle 219 and Particle type 0: 0.1530253142118454
# Particle 220 and Particle type 13: 0.3890603482723236
# Particle 221 and Particle type 13: 41.182865142822266
# Particle 222 and Particle type 22: 3.7718088626861572
# Particle 223 and Particle type 22: 29.423974990844727
# Particle 224 and Particle type 2212: 0.6064289212226868
# Particle 225 and Particle type 13: 1.6133298873901367
# Particle 226 and Particle type 2212: 0.16981607675552368
# Particle 227 and Particle type 2212: 0.1835123747587204
# Particle 228 and Particle type 22: 19.11363410949707
# Particle 229 and Particle type 22: 1.3951215744018555
# Particle 230 and Particle type 22: 0.8391662836074829
# Particle 231 and Particle type 22: 1.062384009361267
# Particle 232 and Particle type 13: 0.4352369010448456
# Particle 233 and Particle type 2212: 0.38856664299964905
# Particle 234 and Particle type 13: 5.870388507843018
# Particle 235 and Particle type 2212: 19.53389549255371
# Particle 237 and Particle type 2212: 0.140380859375
# Particle 238 and Particle type 0: 14.13234806060791
# Particle 239 and Particle type 2212: 0.09065093845129013
# Particle 240 and Particle type 13: 0.8187810778617859
# Particle 241 and Particle type 211: 1.3422520160675049
# Particle 242 and Particle type 2212: 0.11861947923898697
# Particle 243 and Particle type 13: 2.136500120162964
# Particle 244 and Particle type 13: 3.6519572734832764
# Particle 245 and Particle type 2212: 0.3259570896625519
# Particle 246 and Particle type 2212: 0.6952412724494934
# Particle 247 and Particle type 22: 27.14316749572754
# Particle 248 and Particle type 2212: 0.6717491149902344
# Particle 249 and Particle type 13: 4.978416442871094
# Particle 250 and Particle type 13: 5.999601364135742
# Particle 251 and Particle type 321: 0.12358541041612625
# Particle 252 and Particle type -13: 2.1521387100219727
# Particle 253 and Particle type 22: 0.10694709420204163
# Particle 254 and Particle type 22: 29.313356399536133
# Particle 255 and Particle type 22: 1.6254068613052368
# Particle 256 and Particle type 22: 0.764892578125
# Particle 257 and Particle type 13: 2.8961219787597656
# Particle 258 and Particle type 211: 2.680511951446533
# Particle 259 and Particle type 13: 0.3387048840522766
# Particle 260 and Particle type 211: 0.1653645783662796
# Particle 261 and Particle type 2212: 27.186424255371094
# Particle 262 and Particle type 211: 1.1461788415908813
# Particle 263 and Particle type 0: 0.24442312121391296
# Particle 264 and Particle type 13: 1.5693687200546265
# Particle 265 and Particle type 2212: 0.8526190519332886
# Particle 266 and Particle type 2212: 0.7795705199241638
# Particle 267 and Particle type 22: 0.264251708984375
# Particle 268 and Particle type 13: 6.370668411254883
# Particle 269 and Particle type 22: 0.2067081183195114
# Particle 270 and Particle type 2212: 0.524860680103302
# Particle 271 and Particle type 2212: 0.3834228515625
# Particle 272 and Particle type 2212: 0.1999162882566452
# Particle 275 and Particle type 2212: 0.3387857973575592
# Particle 276 and Particle type 2212: 3.159168004989624
# Particle 277 and Particle type 13: 1.4626047611236572
# Particle 278 and Particle type 13: 2.3357114791870117
# Particle 279 and Particle type 13: 97.9412612915039
# Particle 280 and Particle type 13: 0.882843017578125
# Particle 281 and Particle type 2212: 0.112152099609375
# Particle 282 and Particle type 13: 46.20381546020508
# Particle 283 and Particle type 22: 7.145960807800293
# Particle 284 and Particle type 22: 2.578933000564575
# Particle 285 and Particle type 22: 0.0928976908326149
# Particle 286 and Particle type 2212: 0.4990170896053314
# Particle 287 and Particle type 13: 20.38405990600586
# Particle 288 and Particle type 13: 0.955295741558075
# Particle 289 and Particle type 13: 1.3622512817382812
# Particle 290 and Particle type 22: 13.991510391235352
# Particle 291 and Particle type 22: 7.061830520629883
# Particle 292 and Particle type 22: 5.186203956604004
# Particle 293 and Particle type 13: 0.27318137884140015
# Particle 294 and Particle type 2212: 1.3362964391708374
# Particle 295 and Particle type 2212: 0.03885219618678093
# Particle 296 and Particle type 13: 10.07007884979248
# Particle 297 and Particle type 211: 1.9791860580444336
# Particle 298 and Particle type -211: 0.20776571333408356
# Particle 299 and Particle type 2212: 0.7427141666412354
# Particle 301 and Particle type 13: 5.125431060791016
# Particle 302 and Particle type 211: 0.4783225953578949
# Particle 303 and Particle type -11: 0.24755859375
# Particle 305 and Particle type 0: 1.5755201578140259
# Particle 306 and Particle type 13: 3.075465440750122
# Particle 307 and Particle type 211: 0.2331136018037796
# Particle 308 and Particle type 22: 3.4648871421813965
# Particle 309 and Particle type 2212: 1.3900395631790161
# Particle 310 and Particle type 13: 1.967946171760559
# Particle 311 and Particle type 2212: 0.01446533203125
# Particle 312 and Particle type 2212: 0.29562342166900635
# Particle 313 and Particle type -211: 0.3738632798194885
# Particle 314 and Particle type 211: 2.5521326065063477
# Particle 315 and Particle type 0: 0.18861083686351776
# Particle 316 and Particle type -211: 1.1904221773147583
# Particle 317 and Particle type -211: 62.58964538574219
# Particle 318 and Particle type 22: 0.7550936341285706
# Particle 319 and Particle type 2212: 0.481109619140625
# Particle 320 and Particle type 13: 1.6345243453979492
# Particle 321 and Particle type 211: 0.9013137817382812
# Particle 322 and Particle type 13: 2.0138325691223145
# Particle 323 and Particle type 2212: 0.15575560927391052
# Particle 324 and Particle type -211: 0.1197684183716774
# Particle 325 and Particle type 2212: 0.1687469482421875
# Particle 326 and Particle type 0: 0.0107421875
# Particle 327 and Particle type 22: 1.087717890739441
# Particle 328 and Particle type 22: 1.214255928993225
# Particle 329 and Particle type 0: 0.21894530951976776
# Particle 330 and Particle type 0: 0.08629608154296875
# Particle 331 and Particle type 22: 0.4013570249080658
# Particle 333 and Particle type 22: 0.8368415832519531
# Particle 334 and Particle type 22: 0.5450714230537415
# Particle 335 and Particle type -11: 1.0976213216781616
# Particle 336 and Particle type 2212: 1.5649441480636597
# Particle 337 and Particle type 22: 0.42997658252716064
# Particle 339 and Particle type 2212: 25.553638458251953
# Particle 340 and Particle type 2212: 0.408374547958374
# Particle 341 and Particle type 2212: 0.12938766181468964
# Particle 342 and Particle type 13: 29.19242286682129
# Particle 343 and Particle type 13: 4.977987289428711
# Particle 344 and Particle type 13: 12.895486831665039
# Particle 345 and Particle type 2212: 0.196807861328125
# Particle 346 and Particle type 2212: 0.05747375637292862
# Particle 347 and Particle type 22: 16.335290908813477
# Particle 348 and Particle type 22: 1.3890713453292847
# Particle 349 and Particle type 22: 0.6876634359359741
# Particle 350 and Particle type 2212: 1.9849562644958496
# Particle 351 and Particle type 2212: 0.10621055960655212
# Particle 352 and Particle type 2212: 0.16962739825248718
# Particle 353 and Particle type -211: 5.912586688995361
# Particle 354 and Particle type 2212: 0.10120183974504471
# Particle 355 and Particle type -211: 0.36615049839019775
# Particle 356 and Particle type 2212: 0.14725534617900848
# Particle 357 and Particle type 22: 34.052818298339844
# Particle 358 and Particle type 13: 0.3724856972694397
# Particle 359 and Particle type -211: 0.4905191957950592
# Particle 360 and Particle type 2212: 1.7588225603103638
# Particle 362 and Particle type 22: 13.293667793273926
# Particle 363 and Particle type 22: 7.10076904296875
# Particle 364 and Particle type 22: 0.33849138021469116
# Particle 365 and Particle type 13: 9.005517959594727
# Particle 366 and Particle type 2212: 0.9655724763870239
# Particle 367 and Particle type 22: 0.13274601101875305
# Particle 368 and Particle type 2212: 0.1180877685546875
# Particle 369 and Particle type 2212: 8.673601150512695
# Particle 370 and Particle type 0: 0.22127661108970642
# Particle 371 and Particle type 211: 1.0067466497421265
# Particle 372 and Particle type 13: 0.8488296866416931
# Particle 374 and Particle type 211: 0.15024694800376892
# Particle 376 and Particle type -321: 0.0302607212215662
# Particle 377 and Particle type 2212: 0.14273270964622498
# Particle 378 and Particle type 13: 10.465600967407227
# Particle 379 and Particle type 2212: 0.6602053046226501
# Particle 380 and Particle type 2212: 0.17774231731891632
# Particle 381 and Particle type -11: 0.22734883427619934
# Particle 382 and Particle type 211: 0.4359249472618103
# Particle 383 and Particle type 211: 0.626170814037323
# Particle 384 and Particle type 211: 0.8718953728675842
# Particle 385 and Particle type 2212: 0.3115743100643158
# Particle 386 and Particle type -11: 0.28077051043510437
# Particle 387 and Particle type 2212: 0.2953556180000305
# Particle 388 and Particle type 2212: 0.9309956431388855
# Particle 389 and Particle type 0: 0.14081573486328125
# Particle 390 and Particle type -211: 0.14560231566429138
# Particle 391 and Particle type 0: 0.05100250244140625
# Particle 392 and Particle type 13: 0.797678530216217
# Particle 393 and Particle type 0: 0.13062462210655212
# Particle 394 and Particle type -11: 0.886474609375
# Particle 395 and Particle type 13: 0.22045256197452545
# Particle 396 and Particle type 13: 4.843648433685303
# Particle 397 and Particle type 13: 1.0037130117416382
# Particle 398 and Particle type 2212: 1.1555378437042236
# Particle 399 and Particle type 13: 6.459784984588623
# Particle 400 and Particle type 22: 0.8587180972099304
# Particle 401 and Particle type 22: 0.1513410359621048
# Particle 402 and Particle type 0: 0.0710405632853508
# Particle 403 and Particle type 22: 0.8498255014419556
# Particle 404 and Particle type 22: 0.6677464246749878
# Particle 405 and Particle type 22: 0.18976974487304688
# Particle 406 and Particle type 22: 0.09481576830148697
# Particle 407 and Particle type 13: 0.41321444511413574
# Particle 408 and Particle type 13: 0.3588621914386749
# Particle 409 and Particle type 2212: 0.161235511302948
# Particle 410 and Particle type 2212: 0.33883580565452576
# Particle 411 and Particle type 2212: 0.0458221435546875
# Particle 412 and Particle type 2212: 0.28879377245903015
# Particle 413 and Particle type 13: 8.388391494750977
# Particle 414 and Particle type 2212: 2.8479950428009033
# Particle 415 and Particle type -211: 0.4038318991661072
# Particle 416 and Particle type 2212: 0.10887908935546875
# Particle 417 and Particle type -13: 90.6705322265625
# Particle 418 and Particle type 2212: 2.70544171333313
# Particle 419 and Particle type -13: 0.2537580132484436
# Particle 420 and Particle type 22: 1.715267300605774
# Particle 421 and Particle type 22: 3.866487979888916
# Particle 423 and Particle type 22: 0.5873955488204956
# Particle 424 and Particle type 13: 0.35863468050956726
# Particle 426 and Particle type 13: 21.263755798339844
# Particle 427 and Particle type 2212: 0.3437856137752533
# Particle 429 and Particle type -211: 1.2257235050201416
# Particle 430 and Particle type -211: 0.4296985864639282
# Particle 431 and Particle type 13: 12.960780143737793
# Particle 432 and Particle type 211: 0.2385268658399582
# Particle 433 and Particle type 211: 0.10180302709341049
# Particle 434 and Particle type 2212: 0.44498538970947266
# Particle 435 and Particle type 13: 0.15660648047924042
# Particle 436 and Particle type 13: 0.0942796990275383
# Particle 438 and Particle type 211: 0.4674195945262909
# Particle 439 and Particle type 0: 1.3399590253829956
# Particle 441 and Particle type 0: 0.09932861477136612
# Particle 442 and Particle type 2212: 0.1369120329618454
# Particle 443 and Particle type 13: 10.796412467956543
# Particle 444 and Particle type 13: 0.29739615321159363
# Particle 445 and Particle type 211: 2.4144740104675293
# Particle 447 and Particle type 0: 0.12007882446050644
# Particle 448 and Particle type 0: 0.2797967791557312
# Particle 449 and Particle type 2212: 0.07308827340602875
# Particle 450 and Particle type 0: 0.1668192595243454
# Particle 451 and Particle type 2212: 0.16960054636001587
# Particle 452 and Particle type 211: 1.2410914897918701
# Particle 453 and Particle type 2212: 0.4776407778263092
# Particle 455 and Particle type 2212: 10.762185096740723
# Particle 457 and Particle type 2212: 0.31504517793655396
# Particle 458 and Particle type 13: 12.59731674194336
# Particle 459 and Particle type 13: 0.061978790909051895
# Particle 460 and Particle type 0: 0.10931186378002167
# Particle 461 and Particle type 2212: 0.259347528219223
# Particle 462 and Particle type 2212: 0.036865234375
# Particle 463 and Particle type 13: 13.717931747436523
# Particle 464 and Particle type 211: 0.11593238264322281
# Particle 465 and Particle type 2212: 0.3181821405887604
# Particle 466 and Particle type 2212: 0.0760531947016716
# Particle 467 and Particle type 2212: 0.1404321789741516
# Particle 468 and Particle type 0: 0.0787709578871727
# Particle 469 and Particle type 2212: 0.2340833842754364
# Particle 470 and Particle type 2212: 0.0550740547478199
# Particle 471 and Particle type 2212: 0.1595560759305954
# Particle 472 and Particle type 22: 5.25333309173584
# Particle 473 and Particle type 22: 1.7984726428985596
# Particle 474 and Particle type 22: 1.100341796875
# Particle 475 and Particle type 13: 0.5627805590629578
# Particle 476 and Particle type 22: 0.15669602155685425
# Particle 477 and Particle type 22: 0.552272617816925
# Particle 478 and Particle type 22: 2.089679718017578
# Particle 480 and Particle type 2212: 0.05642395094037056
# Particle 481 and Particle type 13: 37.45033264160156
# Particle 482 and Particle type 2212: 0.2012600302696228
# Particle 483 and Particle type 2212: 0.2518119812011719
# Particle 485 and Particle type 2212: 0.13825683295726776
# Particle 487 and Particle type 2212: 0.024576187133789062
# Particle 488 and Particle type 2212: 0.2275138795375824
# Particle 489 and Particle type 0: 0.07773437350988388
# Particle 490 and Particle type 11: 0.16230519115924835
# Particle 491 and Particle type 211: 29.043914794921875
# Particle 492 and Particle type 211: 5.780383586883545
# Particle 493 and Particle type 0: 2.216909646987915
# Particle 494 and Particle type 0: 0.9293242692947388
# Particle 495 and Particle type 0: 0.36119791865348816
# Particle 496 and Particle type 0: 1.638647198677063
# Particle 497 and Particle type 22: 0.17989327013492584
# Particle 498 and Particle type 0: 3.3866448402404785
# Particle 499 and Particle type 13: 20.931360244750977
# Particle 501 and Particle type 13: 1.6376053094863892
# Particle 502 and Particle type 211: 0.7798774838447571
# Particle 503 and Particle type 211: 0.1701139509677887
# Particle 504 and Particle type 0: 0.49441322684288025
# Particle 505 and Particle type 211: 0.18905718624591827
# Particle 506 and Particle type 22: 2.1629278659820557
# Particle 507 and Particle type 13: 12.712821006774902
# Particle 508 and Particle type 2212: 0.5454720258712769
# Particle 509 and Particle type 2212: 3.425177574157715
# Particle 510 and Particle type 2212: 0.33524322509765625
# Particle 511 and Particle type 2212: 0.134765625
# Particle 512 and Particle type 13: 0.5109280943870544
# Particle 513 and Particle type 2212: 1.0364786386489868
# Particle 515 and Particle type 22: 0.9343912601470947
# Particle 516 and Particle type 211: 0.6226323843002319
# Particle 517 and Particle type -211: 0.8995378017425537
# Particle 518 and Particle type -211: 0.9345073103904724
# Particle 519 and Particle type 22: 21.442543029785156
# Particle 520 and Particle type 22: 0.7885423898696899
# Particle 521 and Particle type 211: 0.4702855050563812
# Particle 522 and Particle type 22: 22.90468406677246
# Particle 523 and Particle type 2212: 0.339752197265625
# Particle 524 and Particle type 0: 0.10603027045726776
# Particle 525 and Particle type 2212: 0.8296434879302979
# Particle 526 and Particle type 2212: 2.543309450149536
# Particle 527 and Particle type 211: 1.5706787109375
# Particle 528 and Particle type 2212: 0.45626747608184814
# Particle 529 and Particle type 2212: 0.22043082118034363
# Particle 530 and Particle type 2212: 0.5569127202033997
# Particle 531 and Particle type 22: 6.488186359405518
# Particle 532 and Particle type 22: 0.8219767212867737
# Particle 533 and Particle type 0: 1.067901611328125
# Particle 534 and Particle type 0: 0.4996541440486908
# Particle 535 and Particle type -211: 0.5888782739639282
# Particle 536 and Particle type 13: 1.1868247985839844
# Particle 537 and Particle type -211: 10.125971794128418
# Particle 538 and Particle type -211: 0.565085232257843
# Particle 539 and Particle type 211: 0.3201628029346466
# Particle 540 and Particle type 22: 56.47945022583008
# Particle 542 and Particle type 2212: 0.17633819580078125
# Particle 543 and Particle type 2212: 7.254860877990723
# Particle 544 and Particle type 0: 2.469189167022705
# Particle 545 and Particle type 0: 0.5472233295440674
# Particle 546 and Particle type 2212: 0.49239692091941833
# Particle 547 and Particle type 2212: 0.20537440478801727
# Particle 548 and Particle type 13: 5.0864434242248535
# Particle 549 and Particle type 13: 9.439438819885254
# Particle 550 and Particle type 13: 1.2523473501205444
# Particle 551 and Particle type 211: 0.11704902350902557
# Particle 552 and Particle type -211: 0.16120396554470062
# Particle 553 and Particle type 2212: 0.0398356132209301
# Particle 554 and Particle type 13: 1.6686015129089355
# Particle 555 and Particle type 13: 3.877490520477295
# Particle 556 and Particle type 2212: 0.01851806603372097
# Particle 557 and Particle type 2212: 0.3534698486328125
# Particle 558 and Particle type 13: 18.34161949157715
# Particle 559 and Particle type 211: 0.08830022811889648
# Particle 560 and Particle type 0: 1.1044154167175293
# Particle 561 and Particle type 0: 0.5130977034568787
# Particle 562 and Particle type 2212: 0.949510931968689
# Particle 563 and Particle type 13: 7.5770649909973145
# Particle 564 and Particle type 22: 3.8588554859161377
# Particle 565 and Particle type 22: 32.70355987548828
# Particle 566 and Particle type 22: 28.45167350769043
# Particle 567 and Particle type 211: 0.0887858048081398
# Particle 568 and Particle type 0: 1.1895984411239624
# Particle 569 and Particle type 13: 6.080413818359375
# Particle 571 and Particle type 22: 1.548547387123108
# Particle 572 and Particle type 22: 2.1139934062957764
# Particle 573 and Particle type 2212: 1.0216833353042603
# Particle 574 and Particle type -211: 3.2369577884674072
# Particle 575 and Particle type 2212: 0.3177025318145752
# Particle 576 and Particle type 2212: 0.4711553454399109
# Particle 577 and Particle type 2212: 0.3234349191188812
# Particle 578 and Particle type 13: 0.16839599609375
# Particle 579 and Particle type 0: 0.3277941346168518
# Particle 580 and Particle type 2212: 0.1261698454618454
# Particle 581 and Particle type 2212: 0.091064453125
# Particle 582 and Particle type 2212: 8.678823471069336
# Particle 583 and Particle type 0: 0.956329345703125
# Particle 584 and Particle type 0: 0.12626953423023224
# Particle 585 and Particle type -211: 0.521557629108429
# Particle 586 and Particle type 3112: 0.155364990234375
# Particle 587 and Particle type 2212: 0.32233506441116333
# Particle 588 and Particle type 211: 3.221379280090332
# Particle 589 and Particle type -211: 1.6732772588729858
# Particle 590 and Particle type -211: 0.43581706285476685
# Particle 591 and Particle type 211: 0.7352514863014221
# Particle 592 and Particle type -211: 0.5145161747932434
# Particle 593 and Particle type 0: 1.2879102230072021
# Particle 594 and Particle type -211: 0.35657382011413574
# Particle 595 and Particle type 0: 0.22632554173469543
# Particle 596 and Particle type -13: 4.421792984008789
# Particle 597 and Particle type -11: 0.10293856263160706
# Particle 598 and Particle type 13: 35.77826690673828
# Particle 599 and Particle type 2212: 0.21375137567520142
# Particle 601 and Particle type 11: 0.4232439398765564
# Particle 602 and Particle type 22: 8.351654052734375
# Particle 603 and Particle type 13: 22.241655349731445
# Particle 604 and Particle type 13: 0.26802825927734375
# Particle 605 and Particle type 13: 0.2125447541475296
# Particle 606 and Particle type 211: 0.0491197369992733
# Particle 607 and Particle type 13: 1.5172168016433716
# Particle 608 and Particle type 22: 0.5303080081939697
# Particle 609 and Particle type 22: 0.3198608458042145
# Particle 610 and Particle type 211: 0.662933349609375
# Particle 611 and Particle type 0: 0.657883882522583
# Particle 612 and Particle type 13: 0.3382415771484375
# Particle 613 and Particle type 0: 0.16348877549171448
# Particle 614 and Particle type 13: 0.1110432967543602
# Particle 615 and Particle type 13: 27.146812438964844
# Particle 616 and Particle type 11: 0.25551146268844604
# Particle 617 and Particle type 211: 0.0695604607462883
# Particle 618 and Particle type 211: 0.5249923467636108
# Particle 619 and Particle type 0: 0.1119384765625
# Particle 620 and Particle type 22: 16.298786163330078
# Particle 621 and Particle type 22: 4.842299461364746
# Particle 622 and Particle type 13: 1.298762321472168
# Particle 623 and Particle type 2212: 0.07500220835208893
# Particle 624 and Particle type 22: 0.2593974471092224
# Particle 625 and Particle type 22: 0.2098080813884735
# Particle 626 and Particle type 13: 5.50853157043457
# Particle 627 and Particle type 13: 1.3507275581359863
# Particle 628 and Particle type 13: 0.739426851272583
# Particle 629 and Particle type 22: 0.7095656991004944
# Particle 630 and Particle type 22: 0.0745740607380867
# Particle 631 and Particle type 13: 27.553979873657227
# Particle 632 and Particle type 13: 0.4548095762729645
# Particle 633 and Particle type 22: 23.025955200195312
# Particle 634 and Particle type 22: 39.421974182128906
# Particle 635 and Particle type 22: 0.2073160856962204
# Particle 636 and Particle type 0: 0.2847328186035156
# Particle 637 and Particle type 0: 0.13028717041015625
# Particle 638 and Particle type 211: 0.14117431640625
# Particle 639 and Particle type 22: 0.2720794677734375
# Particle 640 and Particle type 13: 2.649284839630127
# Particle 641 and Particle type 13: 0.6233285665512085
# Particle 642 and Particle type 211: 13.297335624694824
# Particle 643 and Particle type 211: 1.2959927320480347
# Particle 644 and Particle type 2212: 0.7827268838882446
# Particle 645 and Particle type 0: 0.15422821044921875
# Particle 646 and Particle type 22: 3.826091766357422
# Particle 647 and Particle type -211: 1.3559658527374268
# Particle 648 and Particle type 211: 1.2055951356887817
# Particle 649 and Particle type 0: 0.20588989555835724
# Particle 650 and Particle type -211: 2.4236648082733154
# Particle 651 and Particle type -211: 5.045330047607422
# Particle 652 and Particle type 22: 0.4172271192073822
# Particle 653 and Particle type 321: 0.4177374541759491
# Particle 654 and Particle type 2212: 0.05253906175494194
# Particle 655 and Particle type 0: 0.1968536376953125
# Particle 656 and Particle type 2212: 0.05149702727794647
# Particle 657 and Particle type 22: 1.3888306617736816
# Particle 658 and Particle type 22: 4.464789867401123
# Particle 659 and Particle type 13: 0.4682759940624237
# Particle 661 and Particle type -11: 0.343505859375
# Particle 662 and Particle type 22: 38.12016677856445
# Particle 663 and Particle type 22: 0.8379557132720947
# Particle 664 and Particle type 13: 0.0444684699177742
# Particle 665 and Particle type 2212: 0.3009796142578125
# Particle 666 and Particle type 0: 6.064089775085449
# Particle 667 and Particle type 211: 0.8696108460426331
# Particle 668 and Particle type 321: 2.2791965007781982
# Particle 669 and Particle type 211: 4.4670586585998535
# Particle 670 and Particle type -211: 0.5978749394416809
# Particle 671 and Particle type 2212: 0.23317307233810425
# Particle 672 and Particle type 22: 2.1116271018981934
# Particle 673 and Particle type -211: 0.3229329288005829
# Particle 674 and Particle type 13: 11.428730010986328
# Particle 675 and Particle type 0: 0.8342729210853577
# Particle 676 and Particle type 0: 1.2818312644958496
# Particle 677 and Particle type -2212: 0.4894856810569763
# Particle 678 and Particle type 2212: 0.1048380509018898
# Particle 679 and Particle type -211: 0.6272024512290955
# Particle 680 and Particle type 0: 0.0245186947286129
# Particle 681 and Particle type -211: 0.0823122039437294
# Particle 682 and Particle type 2212: 0.4777282774448395
# Particle 683 and Particle type 13: 2.4106361865997314
# Particle 684 and Particle type 2212: 0.1023101806640625
# Particle 685 and Particle type 211: 2.5967798233032227
# Particle 686 and Particle type -211: 0.21970847249031067
# Particle 687 and Particle type 2212: 0.07178289443254471
# Particle 688 and Particle type 13: 3.8828563690185547
# Particle 689 and Particle type 2212: 0.735975980758667
# Particle 690 and Particle type 2212: 0.06479492038488388
# Particle 691 and Particle type 13: 0.10262451320886612
# Particle 692 and Particle type 22: 1.131591796875
# Particle 693 and Particle type 22: 0.23449096083641052
# Particle 694 and Particle type 2212: 0.5731872320175171
# Particle 695 and Particle type 13: 0.08835865557193756
# Particle 697 and Particle type 13: 43.63184356689453
# Particle 698 and Particle type 2212: 0.094970703125
# Particle 699 and Particle type 211: 0.7433800101280212
# Particle 700 and Particle type 13: 0.2881673276424408
# Particle 701 and Particle type -11: 39.62067413330078
# Particle 702 and Particle type -11: 0.660919189453125
# Particle 703 and Particle type -11: 1.1424108743667603
# Particle 704 and Particle type -11: 0.5166778564453125
# Particle 705 and Particle type -11: 0.364501953125
# Particle 706 and Particle type -11: 1.7335635423660278
# Particle 707 and Particle type -11: 0.9435628056526184
# Particle 708 and Particle type -11: 0.5014125108718872
# Particle 709 and Particle type -11: 0.2157772332429886
# Particle 710 and Particle type 22: 0.8590527176856995
# Particle 711 and Particle type -211: 1.7343316078186035
# Particle 712 and Particle type 2212: 2.0004756450653076
# Particle 713 and Particle type 2212: 0.18697968125343323
# Particle 715 and Particle type 2212: 0.6162363886833191
# Particle 716 and Particle type 2212: 0.9991836547851562
# Particle 717 and Particle type 0: 0.5321994423866272
# Particle 718 and Particle type 22: 0.2947326600551605
# Particle 719 and Particle type 2212: 9.252761840820312
# Particle 720 and Particle type 22: 0.8359794616699219
# Particle 721 and Particle type 22: 1.3148574829101562
# Particle 722 and Particle type 22: 0.23529815673828125
# Particle 725 and Particle type 211: 1.1466667652130127
# Particle 726 and Particle type 13: 11.554000854492188
# Particle 727 and Particle type 22: 0.5348085761070251
# Particle 728 and Particle type 22: 2.1370668411254883
# Particle 729 and Particle type 13: 0.9178093671798706
# Particle 730 and Particle type 22: 0.1702008992433548
# Particle 731 and Particle type 13: 0.0989815816283226
# Particle 732 and Particle type 13: 7.605741500854492
# Particle 733 and Particle type 13: 1.5404441356658936
# Particle 734 and Particle type 13: 0.2629132866859436
# Particle 735 and Particle type 22: 27.811607360839844
# Particle 736 and Particle type 0: 0.3918597996234894
# Particle 737 and Particle type 22: 0.2448556125164032
# Particle 738 and Particle type 2212: 0.45271140336990356
# Particle 739 and Particle type 2212: 19.778724670410156
# Particle 740 and Particle type -211: 8.548419952392578
# Particle 741 and Particle type 13: 3.8681137561798096
# Particle 742 and Particle type 2212: 0.3414628803730011
# Particle 743 and Particle type 22: 11.01078987121582
# Particle 744 and Particle type 0: 6.555610656738281
# Particle 745 and Particle type 0: 0.6402511596679688
# Particle 746 and Particle type 211: 0.08940711617469788
# Particle 747 and Particle type 211: 0.7895181179046631
# Particle 748 and Particle type 2212: 0.059844970703125
# Particle 749 and Particle type 2212: 0.0170440673828125
# Particle 750 and Particle type 13: 12.570863723754883
# Particle 751 and Particle type 13: 0.22828368842601776
# Particle 752 and Particle type 0: 0.22888565063476562
# Particle 753 and Particle type 2212: 0.0535685233771801
# Particle 754 and Particle type 13: 133.08961486816406
# Particle 755 and Particle type 22: 47.67985534667969
# Particle 756 and Particle type 22: 5.691863059997559
# Particle 757 and Particle type 22: 1.119671106338501
# Particle 758 and Particle type 13: 1.6935163736343384
# Particle 760 and Particle type 2212: 0.6260528564453125
# Particle 761 and Particle type 22: 0.3788364827632904
# Particle 762 and Particle type 22: 0.23127441108226776
# Particle 763 and Particle type 22: 0.2813991904258728
# Particle 764 and Particle type 22: 0.3763982653617859
# Particle 765 and Particle type 22: 0.1341727077960968
# Particle 766 and Particle type -211: 0.33837890625
# Particle 767 and Particle type 211: 0.27720609307289124
# Particle 768 and Particle type 211: 0.19082322716712952
# Particle 769 and Particle type 0: 0.0954110249876976
# Particle 770 and Particle type 13: 0.33679553866386414
# Particle 771 and Particle type 22: 2.0858426094055176
# Particle 772 and Particle type 2212: 0.17803955078125
# Particle 773 and Particle type 211: 0.1139264777302742
# Particle 774 and Particle type 13: 0.3070075511932373
# Particle 776 and Particle type 22: 1.607324242591858
# Particle 777 and Particle type 211: 1.6062192916870117
# Particle 778 and Particle type 22: 0.3670806884765625
# Particle 779 and Particle type -211: 0.30123335123062134
# Particle 780 and Particle type 13: 0.6099446415901184
# Particle 781 and Particle type 2212: 8.658063888549805
# Particle 782 and Particle type 0: 0.133209228515625
# Particle 783 and Particle type 2212: 0.0755445659160614
# Particle 784 and Particle type 0: 0.39452558755874634
# Particle 785 and Particle type 2212: 0.627076268196106
# Particle 786 and Particle type 2212: 0.12494581937789917
# Particle 787 and Particle type 0: 2.4068100452423096
# Particle 788 and Particle type 2212: 0.2899401783943176
# Particle 789 and Particle type 13: 4.560832500457764
# Particle 790 and Particle type 211: 9.295787811279297
# Particle 791 and Particle type 22: 19.56025505065918
# Particle 792 and Particle type 22: 1.2061227560043335
# Particle 793 and Particle type -211: 0.3126198649406433
# Particle 794 and Particle type 0: 1.1927196979522705
# Particle 795 and Particle type -211: 0.9126848578453064
# Particle 796 and Particle type -211: 0.8465312719345093
# Particle 797 and Particle type 211: 1.2829132080078125
# Particle 798 and Particle type 13: 2.7394745349884033
# Particle 799 and Particle type 211: 10.587518692016602
# Particle 800 and Particle type -211: 24.27281951904297
# Particle 801 and Particle type 2212: 0.7274520993232727
# Particle 802 and Particle type 2212: 1.3064647912979126
# Particle 803 and Particle type 211: 0.205307275056839
# Particle 804 and Particle type -211: 1.054040551185608
# Particle 805 and Particle type 0: 0.09230863302946091
# Particle 806 and Particle type -211: 0.25073906779289246
# Particle 807 and Particle type 0: 0.4140045642852783
# Particle 808 and Particle type 211: 0.3520670533180237
# Particle 809 and Particle type 211: 30.10225486755371
# Particle 810 and Particle type -211: 11.95178508758545
# Particle 812 and Particle type 13: 12.987689971923828
# Particle 813 and Particle type 2212: 0.10022466629743576
# Particle 814 and Particle type 2212: 1.6035325527191162
# Particle 815 and Particle type 13: 5.627692699432373
# Particle 816 and Particle type 22: 24.979427337646484
# Particle 817 and Particle type 22: 38.00449752807617
# Particle 818 and Particle type 0: 1.20219886302948
# Particle 819 and Particle type 13: 0.5728872418403625
# Particle 820 and Particle type 211: 5.2062883377075195
# Particle 821 and Particle type 22: 0.31540846824645996
# Particle 822 and Particle type 22: 0.5655644536018372
# Particle 823 and Particle type 0: 0.2438507080078125
# Particle 824 and Particle type -211: 2.006697416305542
# Particle 825 and Particle type 0: 1.3549212217330933
# Particle 826 and Particle type 2212: 0.125244140625
# Particle 827 and Particle type 0: 0.3228016793727875
# Particle 828 and Particle type 0: 0.07696940004825592
# Particle 830 and Particle type 0: 3.2479984760284424
# Particle 832 and Particle type 13: 2.4875998497009277
# Particle 833 and Particle type 13: 17.02460289001465
# Particle 834 and Particle type 2212: 0.4825572967529297
# Particle 835 and Particle type 2212: 0.3214518129825592
# Particle 836 and Particle type 13: 1.3740426301956177
# Particle 837 and Particle type 2212: 0.4304403066635132
# Particle 838 and Particle type 13: 6.9117631912231445
# Particle 839 and Particle type 13: 9.768019676208496
# Particle 840 and Particle type 11: 0.091522216796875
# Particle 841 and Particle type 2212: 0.09316494315862656
# Particle 842 and Particle type -211: 3.751492977142334
# Particle 843 and Particle type 2212: 0.2930186986923218
# Particle 844 and Particle type 2212: 0.0653279647231102
# Particle 845 and Particle type -211: 2.213068962097168
# Particle 846 and Particle type 2212: 1.9074664115905762
# Particle 847 and Particle type -211: 0.306533545255661
# Particle 848 and Particle type 2212: 10.301055908203125
# Particle 849 and Particle type -13: 10.54155445098877
# Particle 850 and Particle type -13: 20.305753707885742
# Particle 851 and Particle type -13: 1.1662918329238892
# Particle 852 and Particle type -13: 1.5258450508117676
# Particle 853 and Particle type -13: 1.3537956476211548
# Particle 854 and Particle type 22: 51.18803024291992
# Particle 855 and Particle type 22: 10.9148588180542
# Particle 856 and Particle type 22: 1.3037029504776
# Particle 857 and Particle type 13: 0.41372916102409363
# Particle 858 and Particle type 2212: 0.1013590469956398
# Particle 859 and Particle type -211: 12.846550941467285
# Particle 860 and Particle type 211: 0.22539466619491577
# Particle 861 and Particle type 13: 1.7005468606948853
# Particle 862 and Particle type 211: 22.099884033203125
# Particle 863 and Particle type 2212: 0.1852504163980484
# Particle 864 and Particle type 211: 3.2223851680755615
# Particle 865 and Particle type 2212: 0.168975830078125
# Particle 866 and Particle type 2212: 0.0815565288066864
# Particle 867 and Particle type 2212: 0.13011474907398224
# Particle 869 and Particle type 0: 2.393383741378784
# Particle 870 and Particle type 13: 0.9408609867095947
# Particle 871 and Particle type 13: 18.376293182373047
# Particle 872 and Particle type 2212: 7.471751689910889
# Particle 873 and Particle type 2212: 0.13820648193359375
# Particle 874 and Particle type 2212: 1.1459238529205322
# Particle 875 and Particle type 13: 0.9873386025428772
# Particle 876 and Particle type 11: 2.553762197494507
# Particle 877 and Particle type 2212: 0.1421763151884079
# Particle 878 and Particle type 211: 0.1959705501794815
# Particle 879 and Particle type 211: 0.2099873125553131
# Particle 880 and Particle type 2212: 2.9081225395202637
# Particle 881 and Particle type 13: 2.0233893394470215
# Particle 882 and Particle type -211: 1.4335801601409912
# Particle 883 and Particle type -211: 0.23469094932079315
# Particle 884 and Particle type 13: 3.253364086151123
# Particle 885 and Particle type 13: 9.8194580078125
# Particle 886 and Particle type 2212: 1.942285180091858
# Particle 887 and Particle type 13: 20.56532096862793
# Particle 888 and Particle type 2212: 0.7209561467170715
# Particle 889 and Particle type -211: 0.1133502796292305
# Particle 890 and Particle type -11: 0.158050537109375
# Particle 891 and Particle type 2212: 0.032794952392578125
# Particle 892 and Particle type -11: 0.10997314751148224
# Particle 893 and Particle type 211: 13.935559272766113
# Particle 894 and Particle type 22: 0.17467041313648224
# Particle 895 and Particle type 22: 3.95310115814209
# Particle 896 and Particle type -211: 1.9098281860351562
# Particle 897 and Particle type 22: 16.999011993408203
# Particle 898 and Particle type 22: 1.6350256204605103
# Particle 899 and Particle type 13: 6.518710613250732
# Particle 900 and Particle type 2212: 5.38235330581665
# Particle 901 and Particle type 22: 0.0978783518075943
# Particle 902 and Particle type 22: 0.4900868833065033
# Particle 904 and Particle type 22: 0.45250242948532104
# Particle 905 and Particle type 22: 0.33446043729782104
# Particle 906 and Particle type 2212: 0.1021881103515625
# Particle 907 and Particle type 13: 0.555908203125
# Particle 908 and Particle type 22: 0.3439534604549408
# Particle 909 and Particle type 22: 0.3600870668888092
# Particle 910 and Particle type 22: 0.509539008140564
# Particle 911 and Particle type 22: 0.1569163054227829
# Particle 912 and Particle type 13: 0.32670897245407104
# Particle 913 and Particle type 13: 203.4439697265625
# Particle 914 and Particle type 22: 0.24367015063762665
# Particle 915 and Particle type 22: 53.475284576416016
# Particle 916 and Particle type 22: 3.6529386043548584
# Particle 917 and Particle type 22: 3.46978497505188
# Particle 918 and Particle type 0: 0.40382081270217896
# Particle 919 and Particle type 2212: 0.19732344150543213
# Particle 920 and Particle type 13: 0.6141313314437866
# Particle 921 and Particle type -211: 0.8325904607772827
# Particle 922 and Particle type 22: 5.460690498352051
# Particle 923 and Particle type 22: 6.861011981964111
# Particle 924 and Particle type 22: 0.0651681050658226
# Particle 925 and Particle type 211: 0.7566518187522888
# Particle 926 and Particle type 2212: 0.14313964545726776
# Particle 928 and Particle type -13: 2.2523064613342285
# Particle 929 and Particle type -11: 1.3874685764312744
# ...
# Particle 21596 and Particle type 0: 0.1556074321269989
# Particle 21597 and Particle type 22: 3.3965508937835693
# Particle 21598 and Particle type 13: 14.06119441986084
# Particle 21599 and Particle type 0: 0.3820818364620209
# Particle 21600 and Particle type 211: 4.972625255584717
# Particle 21601 and Particle type 2212: 0.2150530070066452
# Particle 21602 and Particle type 13: 63.99321365356445
# Particle 21603 and Particle type 13: 1.1940476894378662
# Particle 21604 and Particle type 13: 19.5715389251709
# Particle 21606 and Particle type 2212: 0.3699595034122467
# Particle 21607 and Particle type -13: 17.8857421875
# Particle 21608 and Particle type -13: 0.4227396547794342
# Particle 21609 and Particle type -13: 0.3916179835796356
# Particle 21610 and Particle type 13: 10.011307716369629
# Particle 21611 and Particle type 0: 0.8460110425949097
# Particle 21612 and Particle type 211: 0.4407528042793274
# Particle 21613 and Particle type 211: 0.439453125
# Particle 21614 and Particle type 13: 20.86634635925293
# Particle 21615 and Particle type 22: 3.4657254219055176
# Particle 21616 and Particle type 22: 7.817806243896484
# Particle 21617 and Particle type 22: 3.0179364681243896
# Particle 21618 and Particle type 22: 0.4713935852050781
# Particle 21619 and Particle type 22: 0.8733852505683899
# Particle 21620 and Particle type 2212: 0.18185894191265106
# Particle 21621 and Particle type -211: 0.27360230684280396
# Particle 21622 and Particle type 211: 0.4238756597042084
# Particle 21623 and Particle type 0: 0.162078857421875
# Particle 21624 and Particle type 22: 2.1711463928222656
# Particle 21625 and Particle type 0: 0.7554213404655457
# Particle 21627 and Particle type 13: 0.1993035227060318
# Particle 21628 and Particle type 211: 0.1387624442577362
# Particle 21630 and Particle type 13: 0.0361735038459301
# Particle 21631 and Particle type 2212: 0.4993347227573395
# Particle 21633 and Particle type 13: 0.15502329170703888
# Particle 21634 and Particle type 2212: 0.09136962890625
# Particle 21635 and Particle type 13: 0.2617891728878021
# Particle 21636 and Particle type 2212: 5.117966175079346
# Particle 21637 and Particle type 13: 15.164690017700195
# Particle 21638 and Particle type 13: 3.14579439163208
# Particle 21639 and Particle type 321: 13.662235260009766
# Particle 21640 and Particle type 13: 10.601850509643555
# Particle 21641 and Particle type 13: 114.425048828125
# Particle 21642 and Particle type 13: 1.168573021888733
# Particle 21643 and Particle type 13: 0.3465006649494171
# Particle 21644 and Particle type 13: 0.6540331244468689
# Particle 21645 and Particle type 2212: 16.037353515625
# Particle 21646 and Particle type 0: 0.1271713227033615
# Particle 21647 and Particle type 13: 0.1773003488779068
# Particle 21648 and Particle type 2212: 0.26698923110961914
# Particle 21649 and Particle type 2212: 0.24989670515060425
# Particle 21650 and Particle type 211: 0.4809825122356415
# Particle 21651 and Particle type 13: 1.51389479637146
# Particle 21652 and Particle type 22: 6.04692268371582
# Particle 21653 and Particle type 2212: 0.6694885492324829
# Particle 21654 and Particle type -211: 0.09265495836734772
# Particle 21655 and Particle type -211: 3.5107204914093018
# Particle 21656 and Particle type 22: 20.476545333862305
# Particle 21657 and Particle type 0: 1.647172212600708
# Particle 21658 and Particle type 321: 0.09847412258386612
# Particle 21659 and Particle type 13: 0.45204925537109375
# Particle 21660 and Particle type 2212: 0.2045665979385376
# Particle 21661 and Particle type -13: 0.14089354872703552
# Particle 21662 and Particle type 2212: 2.575366735458374
# Particle 21663 and Particle type -13: 0.4772135317325592
# Particle 21664 and Particle type -11: 3.361630439758301
# Particle 21665 and Particle type 22: 0.7181221842765808
# Particle 21666 and Particle type 13: 0.6205034255981445
# Particle 21667 and Particle type 2212: 0.13039050996303558
# Particle 21668 and Particle type 22: 0.3538033664226532
# Particle 21669 and Particle type 13: 1.1870918273925781
# Particle 21670 and Particle type 13: 0.5669978260993958
# Particle 21671 and Particle type 13: 48.77825164794922
# Particle 21672 and Particle type 0: 0.9107404351234436
# Particle 21673 and Particle type 0: 0.23915201425552368
# Particle 21674 and Particle type 0: 0.2254486083984375
# Particle 21675 and Particle type 0: 0.2490692138671875
# Particle 21676 and Particle type 2212: 0.3008789122104645
# Particle 21677 and Particle type 13: 10.175952911376953
# Particle 21678 and Particle type 13: 0.583571195602417
# Particle 21680 and Particle type 211: 0.08051876723766327
# Particle 21681 and Particle type 211: 0.27135032415390015
# Particle 21682 and Particle type 13: 1.5458085536956787
# Particle 21684 and Particle type 211: 0.3901268243789673
# Particle 21685 and Particle type -11: 0.4820149838924408
# Particle 21686 and Particle type 13: 0.14994673430919647
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/0j/k5n00ph57w3c1tdfq0lwsgn00000gn/T/ipykernel_30037/3732095278.py in <module>
#       1 for i in eventNumbers:
#       2     r = plotparticles(i)
# ----> 3     plt.hist(r, 21)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1444     def inner(ax, *args, data=None, **kwargs):
#    1445         if data is None:
# -> 1446             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1447
#    1448         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6849                 else:
#    6850                     height = top
# -> 6851                 bars = _barfunc(bins[:-1]+boffset, height, width,
#    6852                                 align='center', log=log,
#    6853                                 color=color, **{bottom_kwarg: bottom})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1444     def inner(ax, *args, data=None, **kwargs):
#    1445         if data is None:
# -> 1446             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1447
#    1448         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2484             else:  # horizontal
#    2485                 r.sticky_edges.x.append(l)
# -> 2486             self.add_patch(r)
#    2487             patches.append(r)
#    2488
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2376         self._set_artist_props(p)
#    2377         if p.get_clip_path() is None:
# -> 2378             p.set_clip_path(self.patch)
#    2379         self._update_patch_limits(p)
#    2380         self._children.append(p)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in set_clip_path(self, path, transform)
#     807             if isinstance(path, Rectangle):
#     808                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 809                                                path.get_transform())
#     810                 self._clippath = None
#     811                 success = True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in get_transform(self)
#     262     def get_transform(self):
#     263         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 264         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     265
#     266     def get_data_transform(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     753         else:
#     754             rotation_point = self.rotation_point
# --> 755         return transforms.BboxTransformTo(bbox) \
#     756                 + transforms.Affine2D() \
#     757                 .translate(-rotation_point[0], -rotation_point[1]) \
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __add__(self, other)
#    1348         ``C.transform(x) == B.transform(A.transform(x))``.
#    1349         """
# -> 1350         return (composite_transform_factory(self, other)
#    1351                 if isinstance(other, Transform) else
#    1352                 NotImplemented)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in composite_transform_factory(a, b)
#    2527     # be IdentityTransforms. Since TransformWrappers are mutable,
#    2528     # use of equality here would be wrong.
# -> 2529     if isinstance(a, IdentityTransform):
#    2530         return b
#    2531     elif isinstance(b, IdentityTransform):
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x17a16dc10> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# -> 2082                 self.draw(*args, **kwargs)
#    2083
#    2084     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    3173
#    3174             self.patch.draw(renderer)
# -> 3175             mimage._draw_list_compositing_images(
#    3176                 renderer, self, artists, self.suppressComposite)
#    3177
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in draw(self, renderer)
#     589         tpath = transform.transform_path_non_affine(path)
#     590         affine = transform.get_affine()
# --> 591         self._draw_paths_with_artist_properties(
#     592             renderer,
#     593             [(tpath, affine,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in _draw_paths_with_artist_properties(self, renderer, draw_path_args_list)
#     574
#     575         for draw_path_args in draw_path_args_list:
# --> 576             renderer.draw_path(gc, *draw_path_args)
#     577
#     578         gc.restore()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     144         else:
#     145             try:
# --> 146                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     147             except OverflowError:
#     148                 cant_chunk = ''
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __array__(self, *args, **kwargs)
#     249
#     250     def __array__(self, *args, **kwargs):
# --> 251         return self.get_points()
#     252
#     253     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in get_points(self)
#    1114             # from the result, taking care to make the orientation the
#    1115             # same.
# -> 1116             points = self._transform.transform(
#    1117                 [[p[0, 0], p[0, 1]],
#    1118                  [p[1, 0], p[0, 1]],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in transform(self, values)
#    1496
#    1497         # Transform the values
# -> 1498         res = self.transform_affine(self.transform_non_affine(values))
#    1499
#    1500         # Convert the result back to the shape of the input values.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in transform_affine(self, points)
#    2421     def transform_affine(self, points):
#    2422         # docstring inherited
# -> 2423         return self.get_affine().transform(points)
#    2424
#    2425     def transform_non_affine(self, points):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in get_affine(self)
#    2448         else:
#    2449             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2450                                    self._a.get_affine().get_matrix()))
#    2451
#    2452     def inverted(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in get_matrix(self)
#    1937         .
#    1938         """
# -> 1939         if self._invalid:
#    1940             self._inverted = None
#    1941             self._invalid = 0
#
# KeyboardInterrupt:
